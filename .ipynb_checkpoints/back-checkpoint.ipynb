# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle 
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, auc , roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.svm import SVC
from sklearn.feature_selection import SelectFromModel
import xgboost

# %%
data = pd.read_csv("Bank_of_America_data.csv")
data_bl = data.dropna()
features = data_bl.iloc[:,1:]
target = data_bl.iloc[:,0]

features_bl = data_bl.iloc[:,1:]
target_bl = data_bl.iloc[:,0]

# %%
encoder = LabelEncoder()
one_hot_encoder = OneHotEncoder()
standard = StandardScaler()

rfc_params = {'max_features':range(1,17)}
knn_params = {'n_neighbors':np.arange(12)*2 +1}
log_params = {'C' : np.logspace(-5,5,40)}
svc_params = {'C' : np.logspace(-5,5,40),'gamma':[0.5,1,2,4,8,10]}
lm_params={'alpha' : np.logspace(-5,5,40)}

rfc_gs_bl = GridSearchCV(RandomForestClassifier(),rfc_params, cv=5)
rfc_gs_fe = GridSearchCV(RandomForestClassifier(n_estimators=100),rfc_params, cv=5)

knn_gs_bl = GridSearchCV(KNeighborsClassifier(),knn_params, cv=5)
knn_gs_fe = GridSearchCV(KNeighborsClassifier(),knn_params, cv=5)

log_gs_bl = GridSearchCV(LogisticRegression(solver='lbfgs', max_iter=400),log_params, cv=5)
log_gs_fe = GridSearchCV(LogisticRegression(solver='lbfgs', max_iter=400),log_params, cv=5)

svc_gs_bl = GridSearchCV(SVC(),svc_params ,cv=5)
svc_gs_fe = GridSearchCV(SVC(),svc_params, cv=5, n_jobs=4)

ridge_gs = GridSearchCV(Ridge(),lm_params, cv=10)

# %%
def fit_model (model, X_train, y_train):
    model.fit(X_train,y_train)

def predict_model(model, X_test):
    return model.predict(X_test)

def score_model(model, prediction, y_test):
    return accuracy_score(y_test, prediction)

def predict_proba_model(model, X_test, proba):
    pred= model.predict_proba(X_test)
    pred[pred > proba]=1
    pred[pred <= proba]=0
    return pred[:,1]

def compete_model(model, X_train, y_train, X_test, y_test, proba=0.5):
    fit_model (model, X_train, y_train)
    try :
        print(confusion_matrix(y_test, predict_proba_model(model,X_test,proba), labels=[0,1]))
    except :
        print("proba is not available")
    pred = predict_model(model, X_test)
    fpr , tpr, threshold = roc_curve(y_test, pred, pos_label=1)
    return [score_model(model, pred, y_test), model.best_estimator_, pd.DataFrame(confusion_matrix(y_test, pred, labels=[0,1]), columns=['pred 0','pred 1'], index=[0,1]), [roc_auc_score(y_test, pred),tpr,fpr]]

# %% [markdown]
# <h2> start by creating training and test sets </h2>

# %%
reason = features_bl.REASON = encoder.fit_transform(features_bl.REASON)
jobs = pd.DataFrame(one_hot_encoder.fit_transform(features_bl.JOB.to_numpy().reshape(-1,1)).toarray(),index=features_bl.index).drop(5,axis=1)
features_bl_numeric = pd.concat([features_bl,jobs],axis=1).drop('JOB',axis=1)
features_bl_numeric.reason = reason
# Out:
# /home/zied/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   after removing the cwd from sys.path.

# %%
features_bl_numeric = pd.DataFrame(standard.fit_transform(features_bl_numeric), columns=features_bl_numeric.columns, index=features_bl_numeric.index)

# %%
X_train_bl, X_test_bl, y_train_bl, y_test_bl =  train_test_split(features_bl_numeric, target_bl)

# %% [markdown]
# <h2> let's start with the full data <h2>

# %%
compete_model(rfc_gs_bl, X_train_bl, y_train_bl, X_test_bl, y_test_bl)
# Out:
# [0.9571938168846611,
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                         max_depth=None, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=11,
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False),
#  array([[771,   0],
#         [ 36,  34]]),
#  0.7428571428571429]

# %%
compete_model(svc_gs_bl, X_train_bl, y_train_bl, X_test_bl, y_test_bl)
# Out:
# [0.9678953626634959,
#  SVC(C=272.8333376486764, cache_size=200, class_weight=None, coef0=0.0,
#      decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#      max_iter=-1, probability=False, random_state=None, shrinking=True,
#      tol=0.001, verbose=False),
#  array([[767,   3],
#         [ 24,  47]]),
#  0.8290378635449058]

# %%
compete_model(knn_gs_bl, X_train_bl, y_train_bl, X_test_bl, y_test_bl)
# Out:
# [0.9595719381688466,
#  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                       weights='uniform'),
#  array([[770,   0],
#         [ 34,  37]]),
#  0.7605633802816901]

# %%
compete_model(log_gs_bl, X_train_bl, y_train_bl, X_test_bl, y_test_bl)
# Out:
# /home/zied/.local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# [0.9036860879904876,
#  LogisticRegression(C=1.3433993325988987, class_weight=None, dual=False,
#                     fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                     max_iter=400, multi_class='warn', n_jobs=None, penalty='l2',
#                     random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                     warm_start=False),
#  array([[760,   2],
#         [ 79,   0]])]

# %% [markdown]
# <h1> the data is missing many lines <h1>
#     <hr>
#     <h3>let-s start by understanding the data</h3>

# %%
data.head()
# Out:
#    BAD  LOAN  MORTDUE     VALUE   REASON     JOB   YOJ  DEROG  DELINQ  \
# 0    1  1100  25860.0   39025.0  HomeImp   Other  10.5    0.0     0.0
# 1    1  1300  70053.0   68400.0  HomeImp   Other   7.0    0.0     2.0
# 2    1  1500  13500.0   16700.0  HomeImp   Other   4.0    0.0     0.0
# 3    1  1500      NaN       NaN      NaN     NaN   NaN    NaN     NaN
# 4    0  1700  97800.0  112000.0  HomeImp  Office   3.0    0.0     0.0
#
#         CLAGE  NINQ  CLNO  DEBTINC
# 0   94.366667   1.0   9.0      NaN
# 1  121.833333   0.0  14.0      NaN
# 2  149.466667   1.0  10.0      NaN
# 3         NaN   NaN   NaN      NaN
# 4   93.333333   0.0  14.0      NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5960 entries, 0 to 5959
# Data columns (total 12 columns):
# LOAN       5960 non-null int64
# MORTDUE    5442 non-null float64
# VALUE      5848 non-null float64
# REASON     5708 non-null object
# JOB        5681 non-null object
# YOJ        5445 non-null float64
# DEROG      5252 non-null float64
# DELINQ     5380 non-null float64
# CLAGE      5652 non-null float64
# NINQ       5450 non-null float64
# CLNO       5738 non-null float64
# DEBTINC    4693 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 558.9+ KB

# %%
pd.plotting.scatter_matrix(features, figsize=(20,20));

# %%
print("null values "+str(sum(data.LOAN.isna())))
sns.distplot(data.LOAN)
# Out:
# null values 0

# %%
sns.boxplot(data.LOAN)

# %% [raw]
# ppl with LOAN over 40000 have few non null values

# %%
data[data.LOAN > 40000].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 292 entries, 5668 to 5959
# Data columns (total 13 columns):
# BAD        292 non-null int64
# LOAN       292 non-null int64
# MORTDUE    244 non-null float64
# VALUE      284 non-null float64
# REASON     289 non-null object
# JOB        279 non-null object
# YOJ        242 non-null float64
# DEROG      281 non-null float64
# DELINQ     270 non-null float64
# CLAGE      290 non-null float64
# NINQ       277 non-null float64
# CLNO       292 non-null float64
# DEBTINC    237 non-null float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 31.9+ KB

# %%
sns.distplot(data.MORTDUE.dropna())

# %%
sns.boxplot(data.MORTDUE.dropna())

# %%
data[data.MORTDUE > 150000].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 285 entries, 140 to 5929
# Data columns (total 13 columns):
# BAD        285 non-null int64
# LOAN       285 non-null int64
# MORTDUE    285 non-null float64
# VALUE      280 non-null float64
# REASON     280 non-null object
# JOB        283 non-null object
# YOJ        272 non-null float64
# DEROG      257 non-null float64
# DELINQ     277 non-null float64
# CLAGE      273 non-null float64
# NINQ       270 non-null float64
# CLNO       282 non-null float64
# DEBTINC    226 non-null float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 31.2+ KB

# %%
sns.distplot(data.VALUE.dropna())

# %%
sns.boxplot(data.VALUE.dropna())

# %%
data.REASON.value_counts()
# Out:
# DebtCon    3928
# HomeImp    1780
# Name: REASON, dtype: int64

# %%
data.JOB.value_counts()
# Out:
# Other      2388
# ProfExe    1276
# Office      948
# Mgr         767
# Self        193
# Sales       109
# Name: JOB, dtype: int64

# %%
plt.figure(figsize=(20,14))
sns.barplot(data.YOJ.value_counts().index,data.YOJ.value_counts().values )

# %%
plt.figure(figsize=(20,14))
sns.barplot(data.DEROG.value_counts().index,data.DEROG.value_counts().values )
print(sum(data.DEROG.isna()))
# Out:
# 708

# %%
#it is clearly here that derog = 0 means unkown 
print(data[data.DEROG==1].BAD.sum())
data.BAD.sum()
# Out:
# 43
# 1189

# %%
#there is no unfluence because the proportions are the same  
print(data[data.REASON=='HomeImp'].BAD.sum()/ data[data.REASON=='HomeImp'].BAD.count())
print(data[data.REASON=='DebtCon'].BAD.sum()/data[data.REASON=='DebtCon'].BAD.count())
data[data.REASON.isna()].BAD.sum()/data[data.REASON.isna()].BAD.count()
# Out:
# 0.22247191011235956
# 0.18966395112016293
# 0.19047619047619047

# %%
#there is no unfluence because the proportions are the same  
print(data[data.YOJ==0].BAD.sum()/data[data.YOJ==0].BAD.count())
print(data[(data.YOJ>0)&(data.YOJ<8)].BAD.sum()/data[(data.YOJ>0)&(data.YOJ<8)].BAD.count())
print(data[data.YOJ>7].BAD.sum()/data[data.YOJ>7].BAD.count())
# Out:
# 0.13975903614457832
# 0.23764021603656002
# 0.18897338403041825

# %%
#number de credit lignes
plt.figure(figsize=(20,14))
sns.barplot(data.CLNO.value_counts().index,data.CLNO.value_counts().values )

# %%
#number de credit lignes en souffrances
plt.figure(figsize=(20,14))
sns.barplot(data.DELINQ.value_counts().index,data.DELINQ.value_counts().values )

# %%
sns.distplot(data.CLAGE.dropna())

# %%
#number de credit lignes
plt.figure(figsize=(20,14))
sns.barplot(data.NINQ.value_counts().index,data.NINQ.value_counts().values )

# %%
sns.distplot(data.DEBTINC.dropna())

# %%
print(data[data.DEBTINC<data.DEBTINC.mean()].BAD.sum()/data[data.DEBTINC<data.DEBTINC.mean()].BAD.count())
print(data[data.DEBTINC>data.DEBTINC.mean()].BAD.sum()/data[data.DEBTINC>data.DEBTINC.mean()].BAD.count())
print(data[data.DEBTINC>data.DEBTINC.quantile(0.965)].BAD.sum()/data[data.DEBTINC>data.DEBTINC.quantile(0.965)].BAD.count())
print(data[data.DEBTINC.isna()].BAD.sum()/data[data.DEBTINC.isna()].BAD.count())

print(data.DEBTINC.quantile(0.98))
# Out:
# 0.05718404613166747
# 0.10872894333843798
# 0.6121212121212121
# 0.6203630623520127
# 44.48221963099999

# %%
sns.scatterplot(data.MORTDUE, data.VALUE)

# %% [markdown]
# <h2> creating coef and intercept for relation between mortdue and value </h2>

# %%
ridge_gs.fit(data_bl.MORTDUE.values.reshape(-1,1),data_bl.VALUE)
lm = ridge_gs.best_estimator_
#value = mortdue* coef + intercept

# %% [markdown]
# <h2>changing null values </h2>

# %%
data_fe = data.dropna(thresh=5)
data_fe.REASON.fillna("other",inplace=True)
data_fe.JOB.fillna("Other",inplace=True)
data_fe.DEROG.fillna(0,inplace=True)
data_fe.YOJ.fillna(0,inplace=True)

#data_fe.CLNO.fillna(0,inplace=True)
data_fe.NINQ.fillna(0,inplace=True)
data_fe.DELINQ.fillna(0,inplace=True)

#adding new column for debinc
#data_fe = pd.concat([data_fe, pd.Series(~data_fe.DEBTINC.isna()*1,index=data_fe.index,name="debtincisnull")],axis=1)
data_fe.CLAGE.fillna(data.CLAGE.mean(),inplace=True)
data_fe.DEBTINC.fillna(data.DEBTINC.mean(),inplace=True)
data_fe = data_fe[(~data_fe.MORTDUE.isna())|(~data_fe.VALUE.isna())]

data_fe.MORTDUE.fillna(data_fe.VALUE/lm.coef_ - lm.intercept_,inplace=True)
data_fe.VALUE.fillna(data_fe.MORTDUE*lm.coef_ + lm.intercept_, inplace=True)
# Out:
# /home/zied/.local/lib/python3.7/site-packages/pandas/core/generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
data_fe=data_fe.dropna()
features_fe=data_fe.iloc[:,1:]
target_fe=data_fe.iloc[:,0]
data_fe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5723 entries, 0 to 5959
# Data columns (total 14 columns):
# BAD              5723 non-null int64
# LOAN             5723 non-null int64
# MORTDUE          5723 non-null float64
# VALUE            5723 non-null float64
# REASON           5723 non-null object
# JOB              5723 non-null object
# YOJ              5723 non-null float64
# DEROG            5723 non-null float64
# DELINQ           5723 non-null float64
# CLAGE            5723 non-null float64
# NINQ             5723 non-null float64
# CLNO             5723 non-null float64
# DEBTINC          5723 non-null float64
# debtincisnull    5723 non-null int64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 670.7+ KB

# %% [markdown]
# <h1>creating datasets </h1>

# %%
reason_fe = pd.DataFrame(one_hot_encoder.fit_transform(features_fe.REASON.to_numpy().reshape(-1,1)).toarray(), index=features_fe.index,columns=[10,20,30]).drop(30,axis=1)
jobs_fe = pd.DataFrame(one_hot_encoder.fit_transform(features_fe.JOB.to_numpy().reshape(-1,1)).toarray(),index=features_fe.index).drop(5,axis=1)
features_fe_numeric = pd.concat([features_fe.drop(['REASON','JOB'],axis=1), reason_fe, jobs_fe],axis=1)

# %%
reason_encodage = {}
for e in zip(pd.concat([features_fe.REASON,features_fe_numeric[[10,20]]],axis=1).groupby("REASON").first().values,pd.concat([features_fe.REASON,features_fe_numeric[[10,20]]],axis=1).groupby("REASON").first().index):
    try :
        reason_encodage[e[1]] = 10*(list(e[0]).index(1)+1)
    except:
        reason_encodage[e[1]] = 30

print(reason_encodage)
# Out:
# {'DebtCon': 10, 'HomeImp': 20, 'other': 30}

# %%
job_encodage = {}
for e in zip(pd.concat([features_fe.JOB,features_fe_numeric[[0,1,2,3,4]]],axis=1).groupby("JOB").first().values,pd.concat([features_fe.JOB,features_fe_numeric[[0,1,2,3,4]]],axis=1).groupby("JOB").first().index):
    try :
        job_encodage[e[1]] = list(e[0]).index(1)
    except:
        job_encodage[e[1]] = 5


print(job_encodage)
# Out:
# {'Mgr': 0, 'Office': 1, 'Other': 2, 'ProfExe': 3, 'Sales': 4, 'Self': 5}

# %%
features_fe_numeric = pd.DataFrame(standard.fit_transform(features_fe_numeric), columns=features_fe_numeric.columns, index=features_fe_numeric.index)

# %%
X_train_fe, X_test_fe, y_train_fe, y_test_fe =  train_test_split(features_fe_numeric, target_fe, test_size=0.25)

# %% [markdown]
# <h1> testing </h1>

# %%
compete_model(rfc_gs_fe, X_train_fe, y_train_fe, X_test_fe, y_test_fe)
# Out:
# [[1108   53]
#  [  83  187]]
# [0.9049615653389238,
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=3, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=100,
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False),
#     pred 0  pred 1
#  0    1108      53
#  1      83     187,
#  [0.8234711455641689,
#   array([0.        , 0.69259259, 1.        ]),
#   array([0.       , 0.0456503, 1.       ])]]

# %%
compete_model(svc_gs_fe, X_train_fe, y_train_fe, X_test_fe, y_test_fe)
# Out:
# proba is not available
# [0.9105520614954578,
#  SVC(C=4.37547937507418, cache_size=200, class_weight=None, coef0=0.0,
#      decision_function_shape='ovr', degree=3, gamma=0.5, kernel='rbf',
#      max_iter=-1, probability=False, random_state=None, shrinking=True,
#      tol=0.001, verbose=False),
#     pred 0  pred 1
#  0    1101      60
#  1      68     202,
#  [0.8482342807924202,
#   array([0.        , 0.74814815, 1.        ]),
#   array([0.        , 0.05167959, 1.        ])]]

# %%
compete_model(knn_gs_fe, X_train_fe, y_train_fe, X_test_fe, y_test_fe)
# Out:
# [[1115   15]
#  [  89  212]]
# [0.9273235499650594,
#  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                       weights='uniform'),
#     pred 0  pred 1
#  0    1115      15
#  1      89     212,
#  [0.8455223002969453,
#   array([0.        , 0.70431894, 1.        ]),
#   array([0.        , 0.01327434, 1.        ])]]

# %%
compete_model(log_gs_fe, X_train_fe, y_train_fe, X_test_fe, y_test_fe)
# Out:
# [[888  20]
#  [164  73]]
# [0.8393013100436681,
#  LogisticRegression(C=0.021544346900318822, class_weight=None, dual=False,
#                     fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                     max_iter=400, multi_class='warn', n_jobs=None, penalty='l2',
#                     random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                     warm_start=False),
#     pred 0  pred 1
#  0     888      20
#  1     164      73,
#  [0.6429952229595346,
#   array([0.        , 0.30801688, 1.        ]),
#   array([0.        , 0.02202643, 1.        ])]]

# %% [markdown]
# <h3> now with xgboost </h3>

# %%
data_xg = data.dropna(thresh=5)
data_xg.REASON.fillna("other",inplace=True)
data_xg.JOB.fillna("Other",inplace=True)
# Out:
# /home/zied/.local/lib/python3.7/site-packages/pandas/core/generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
features_xg=data_xg.iloc[:,1:]
target_xg=data_xg.iloc[:,0]

# %%
reason_fe = pd.DataFrame(one_hot_encoder.fit_transform(features_xg.REASON.to_numpy().reshape(-1,1)).toarray(), index=features_xg.index,columns=[10,20,30]).drop(30,axis=1)
jobs_fe = pd.DataFrame(one_hot_encoder.fit_transform(features_xg.JOB.to_numpy().reshape(-1,1)).toarray(),index=features_xg.index).drop(5,axis=1)
features_xg_numeric = pd.concat([features_xg.drop(['REASON','JOB'],axis=1), reason_fe, jobs_fe],axis=1)

# %%
X_train_xg, X_test_xg, y_train_xg, y_test_xg =  train_test_split(features_xg_numeric, target_xg, test_size=0.2)

# %%
xgb_params={ 'reg_alpha': [0.1e-2 ,0.1e-1, 0.1,1]}

# %%
xgb_gs = GridSearchCV(xgboost.XGBClassifier(colsample_bytree= 0.357, subsample= 0.67,learning_rate=0.3,n_estimators=1000,max_depth=5, min_child_weight=1 ,n_jobs=4),xgb_params, cv=5)

# %%
compete_model(xgb_gs, X_train_xg, y_train_xg, X_test_xg, y_test_xg)
# Out:
# [[910  25]
#  [ 66 179]]
# [0.9228813559322034,
#  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=0.357, gamma=0,
#                learning_rate=0.3, max_delta_step=0, max_depth=5,
#                min_child_weight=1, missing=None, n_estimators=1000, n_jobs=4,
#                nthread=None, objective='binary:logistic', random_state=0,
#                reg_alpha=1, reg_lambda=1, scale_pos_weight=1, seed=None,
#                silent=None, subsample=0.67, verbosity=1),
#     pred 0  pred 1
#  0     910      25
#  1      66     179,
#  [0.8519371384917602,
#   array([0.        , 0.73061224, 1.        ]),
#   array([0.        , 0.02673797, 1.        ])]]

# %%
from sklearn.decomposition import PCA, KernelPCA

# %%
kpca = KernelPCA(n_components= 2, degree=3)
kpca.fit(features_fe_numeric.drop([10,20,0,1,2,3,4],axis=1))

pca = PCA(n_components= 2)
pca.fit(StandardScaler().fit_transform(features_bl.drop(['JOB','REASON'],axis=1)))
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(kpca.transform(StandardScaler().fit_transform(features_bl.drop(['JOB','REASON'])[:,0],kpca.transform(StandardScaler().fit_transform(features_bl.drop(['JOB','REASON'][:,1],hue=target_fe)

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(pca.transform(StandardScaler().fit_transform(features_bl.drop(['JOB','REASON'])[:,0],pca.transform(StandardScaler().fit_transform(features_bl.drop(['JOB','REASON'])[:,1],hue=target_fe)
# Out:
#   File "<ipython-input-128-624747350ee6>", line 2
#     sns.scatterplot(pca.transform(StandardScaler().fit_transform(features_bl.drop(['JOB','REASON'])[:,0],pca.transform(StandardScaler().fit_transform(features_bl.drop(['JOB','REASON'])[:,1],hue=target_fe)
#                                                                                                                                                                                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.figure(figsize=(20,20))
for i in range(len(pca.components_[0])):
    plt.plot([0,pca.components_[0][i]],[0,pca.components_[1][i]])
    plt.text(pca.components_[0][i],pca.components_[1][i],features_fe_numeric.columns[i])
plt.xlim([-1,1])
plt.ylim([-1,1])
plt.plot([-1,1],[0,0])
plt.plot([0,0],[-1,1])
